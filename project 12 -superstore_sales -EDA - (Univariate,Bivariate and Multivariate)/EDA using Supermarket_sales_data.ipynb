# %% [markdown]
# **Dataset:** https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('supermarket_sales - Sheet1.csv',parse_dates=['Date'])

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Attribute information :
# - Invoice id: Computer generated sales slip invoice identification number
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
# - City: Location of supercenters
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
# - Gender: Gender type of customer
# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and - beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in $
# - Quantity: Number of products purchased by customer
# - Tax: 5% tax fee for customer buying
# - Total: Total price including tax
# - Date: Date of purchase (Record available from January 2019 to March 2019)
# - Time: Purchase time (10am to 9pm)
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
# - COGS: Cost of goods sold
# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# # 1. Display Top 5 Rows of the dataset

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %% [markdown]
# # 2. Display Last 5 Rows of the dataset

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6

# %% [markdown]
# # 3. Print Random 5 rows from our dataset

# %%
data.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 710  786-94-2700      A     Yangon        Member    Male   Food and beverages
# 72   510-95-6347      B   Mandalay        Member  Female   Food and beverages
# 551  582-52-8065      B   Mandalay        Normal  Female  Fashion accessories
# 269  731-14-2199      A     Yangon        Member  Female   Home and lifestyle
# 79   756-01-7507      C  Naypyitaw        Normal  Female    Health and beauty
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time  Payment  \
# 710       80.62         6  24.1860  507.9060 2019-02-28  20:18     Cash
# 72        48.52         3   7.2780  152.8380 2019-03-05  18:17  Ewallet
# 551       54.31         9  24.4395  513.2295 2019-02-22  10:49     Cash
# 269       35.54        10  17.7700  373.1700 2019-01-04  13:34  Ewallet
# 79        20.38         5   5.0950  106.9950 2019-01-22  18:56     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 710  483.72                 4.761905       24.1860     9.1
# 72   145.56                 4.761905        7.2780     4.0
# 551  488.79                 4.761905       24.4395     8.9
# 269  355.40                 4.761905       17.7700     7.0
# 79   101.90                 4.761905        5.0950     6.0

# %% [markdown]
# # 4. Find the shape of our dataset ( Number of Rows and Number of Columns)

# %%
data.shape
# Out:
# (1000, 17)

# %%
print("Number of rows = ",data.shape[0])
print("Number of columns = ",data.shape[1])
# Out:
# Number of rows =  1000
# Number of columns =  17

# %% [markdown]
# # 5. Check for Null Values in the Dataset

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
# visual representation of null values in dataset

sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # 6. Get information About our dataset like total number Rows, total number of columns, datatypes of each column and memory requirement.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(8)
# memory usage: 132.9+ KB

# %% [markdown]
# # 7. Get overall statistics about the dataset

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000

# %% [markdown]
# # Univariate Analysis

# %%
# let's seperate categorical columns and numerical columns 

cat=[]
num=[]
for column in data.columns:
    if data[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)

# %%
# now check category columns
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
# These are numerical columns
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# ## 1. Find Aggregates Sales Among Branches (Categorical column)

# %%
sns.countplot(data['Branch']) # there is not much difference between these three branches
plt.show()

# %%
data['Branch'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.show()

# %%
data['Branch'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# # 2 . Find the Most Popular Payment Method Used By Customers (Categorical Column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
data['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
sns.countplot(data['Payment'], data = data)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %% [markdown]
# # 3. Find the Distribution of Customer Ratings. (Numerical Column)

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.distplot(data['Rating'])
plt.show()

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# # 4. Find the distribution of Cost of Goods Sold (Numerical Column)

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.distplot(data['cogs'])
plt.show()

# %%
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
# also we can use boxplot

sns.boxplot(data['cogs'])    # here we can see there are ouliers in the data
plt.show()

# %% [markdown]
# # Bivariate Analysis / Multivariate Analysis
#
# # # 1. Does the cost of Goods Sold Affect the Ratings that the Customers Provide? (Numerical - Numerical)

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(x='cogs',y='Rating', data=data)   # Here we can see there is no relationship between them
plt.show()

# %% [markdown]
# ## 2. Does Gross income Affect The Ratings that the customers Provide? (Numerical-Numerical)

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(data['gross income'],data['Rating']) # here there is no relation ship between gross income and rating
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# ## 3. Find the most profitable Branch As per Gross Income. (Numerical - Categorical )

# %%
sns.barplot(data['Branch'],data['Rating'])
plt.show()

# %%
sns.barplot(data['Branch'],data['Rating'],hue=data['City'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %% [markdown]
# ## 4. Is there any Relationship between Gender and Gross income? (Numerical-Categorical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(data['Gender'],data['gross income'])
plt.show()

# %%
sns.boxplot(data['Gender'],data['gross income'])
plt.show()

# %%
sns.boxplot(data['Gender'],data['gross income'],hue=data['Customer type'])
plt.show()

# %% [markdown]
# ## 5. Find the product line that generates the most income. (Numerical - Categorical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
sns.barplot(data['Product line'],data['gross income'])
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ## 6. Find the highest Unit Price in the Product line. (Numerical-Categorical)

# %%
sns.barplot(data['Product line'],data['Unit price'])
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## 7. Find different Payments methods used by Customers Citywise. (Categorical-Categorical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.groupby('City')['Payment'].value_counts()
# Out:
# City       Payment
# Mandalay   Ewallet        113
#            Cash           110
#            Credit card    109
# Naypyitaw  Cash           124
#            Ewallet        106
#            Credit card     98
# Yangon     Ewallet        126
#            Cash           110
#            Credit card    104
# Name: Payment, dtype: int64

# %%
pd.crosstab(data['City'],data['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='City'>

# %% [markdown]
# ## 8. Which Product line is purchased in the highest quantity?

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data['Product line'],data['Quantity'])  # Here we can see Electroni Accesories have highest quantity.
plt.xticks(rotation=30)
plt.show()

# %%
data.groupby('Product line').sum()['Quantity']
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %% [markdown]
# ## 9. Display daily sales by day of the week

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dw_mapping={0:'Mon',
            1:'Tue',
            2:'Wed',
            3:'Thu',
            4:'Fri',
            5:'Sat',
            6:'Sun'
}

# %%
data['day_of_week']=data['Date'].dt.dayofweek.map(dw_mapping)

# %%
data['day_of_week'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## 10. What will be the highest Months of Sales?

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'day_of_week'],
#       dtype='object')

# %%
month_mapping={
               1:'Jan',
               2:'Feb',
               3:'Mar'
}

# %%
data['month']= data['Date'].dt.month.map(month_mapping)

# %%
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating day_of_week month
# 0                 4.761905       26.1415     9.1         Sat   Jan

# %%
data['month'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
